# %%
# !git clone https://github.com/physionetchallenges/python-classifier-2020.git
# Out:
# Cloning into 'python-classifier-2020'...
# remote: Enumerating objects: 46, done.
# remote: Total 46 (delta 0), reused 0 (delta 0), pack-reused 46
# Unpacking objects: 100% (46/46), done.

# %%
# %run '/content/drive/My Drive/ECG_code_sources/DataLoad.ipynb'
# Out:
# --2020-04-30 22:59:15--  https://cloudypipeline.com:9555/api/download/physionet2020training/PhysioNetChallenge2020_Training_CPSC.tar.gz/
# Resolving cloudypipeline.com (cloudypipeline.com)... 34.74.104.185
# Connecting to cloudypipeline.com (cloudypipeline.com)|34.74.104.185|:9555... connected.
# HTTP request sent, awaiting response... 200
# Length: 859926186 (820M) [application/octet-stream]
# Saving to: ‘PhysioNetChallenge2020_Training_CPSC.tar.gz’
#
# PhysioNetChallenge2 100%[===================>] 820.09M  34.8MB/s    in 25s
#
# 2020-04-30 22:59:40 (33.2 MB/s) - ‘PhysioNetChallenge2020_Training_CPSC.tar.gz’ saved [859926186/859926186]

# %%
# Note that you should make output folder at /content/

# %%
# %cd 'python-classifier-2020'
# Out:
# /content/python-classifier-2020

# %%
# !python3 'driver.py' '/content/Training_WFDB' '/content/output'
# Out:
# Streaming output truncated to the last 5000 lines.
#     1880/6877...
#     1881/6877...
#     1882/6877...
#     1883/6877...
#     1884/6877...
#     1885/6877...
#     1886/6877...
#     1887/6877...
#     1888/6877...
#     1889/6877...
#     1890/6877...
#     1891/6877...
#     1892/6877...
#     1893/6877...
#     1894/6877...
#     1895/6877...
#     1896/6877...
#     1897/6877...
#     1898/6877...
#     1899/6877...
#     1900/6877...
#     1901/6877...
#     1902/6877...
#     1903/6877...
#     1904/6877...
#     1905/6877...
#     1906/6877...
#     1907/6877...
#     1908/6877...
#     1909/6877...
#     1910/6877...
#     1911/6877...
#     1912/6877...
#     1913/6877...
#     1914/6877...
#     1915/6877...
#     1916/6877...
#     1917/6877...
#     1918/6877...
#     1919/6877...
#     1920/6877...
#     1921/6877...
#     1922/6877...
#     1923/6877...
#     1924/6877...
#     1925/6877...
#     1926/6877...
#     1927/6877...
#     1928/6877...
# ...
