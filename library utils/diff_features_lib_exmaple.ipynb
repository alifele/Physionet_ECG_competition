# %%
! git clone https://github.com/alifele/Physionet_ECG_competition.git
# Out:
# Cloning into 'Physionet_ECG_competition'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 57 (delta 22), reused 35 (delta 9), pack-reused 0
# Unpacking objects: 100% (57/57), done.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import argrelextrema

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import io
import sys
sys.path.append('/content/Physionet_ECG_competition/library')

# %%
# %run "/content/Physionet_ECG_competition/library/DataLoad.ipynb"
# Out:
# --2020-05-22 12:06:23--  https://cloudypipeline.com:9555/api/download/physionet2020training/PhysioNetChallenge2020_Training_CPSC.tar.gz/
# Resolving cloudypipeline.com (cloudypipeline.com)... 34.74.104.185
# Connecting to cloudypipeline.com (cloudypipeline.com)|34.74.104.185|:9555... connected.
# HTTP request sent, awaiting response... 200
# Length: 859926186 (820M) [application/octet-stream]
# Saving to: ‘PhysioNetChallenge2020_Training_CPSC.tar.gz’
#
# PhysioNetChallenge2 100%[===================>] 820.09M  35.3MB/s    in 23s
#
# 2020-05-22 12:06:47 (35.2 MB/s) - ‘PhysioNetChallenge2020_Training_CPSC.tar.gz’ saved [859926186/859926186]

# %% [markdown]
# # Fetchin single data and extracting the diff features

# %%
import diff_features_lib
import data_fetch

# %%
data = data_fetch.data_loader('A6349.mat')
info = data_fetch.Get_Info('A6349.hea')

# %%
plt.plot(data[:,4])

# %%
info
# Out:
# [47, 0, 5]

# %%
diff_features = diff_features_lib.diff_data(data, append_mode = 'mean_append')

# %%
fig = plt.figure(figsize = (8,5))
for i in range(3):
  ax = fig.add_subplot(3,1,i+1)
  ax.plot(diff_features[i])
  ax.plot(diff_features[i], 'o')

# %% [markdown]
# # Fetcing a batch of data and extracting the diff features

# %%
names = ['A6349', 'A6346', 'A4577', 'A2358', 'A1457', 'A4125']

# %%
data, info = data_fetch.batch_loader(names)

# %%
info
# Out:
# [[47, 0, 5], [65, 0, 4], [25, 1, 6], [53, 1, 7], [72, 1, 1], [80, 0, 6]]

# %%
diff_features_list = diff_features_lib.diff_feature_batch(data)

# %%
fig = plt.figure(figsize=(14,8))
for i in range(3):
  ax = fig.add_subplot(3,1,i+1)
  ax.plot(diff_features_list[0][:,i])
  ax.plot(diff_features_list[0][:,i],'8')
